# %%
a = input("Введите А: ")
print(a)

# %%
ages = [15, 16, 16, 16, 17, 26, 15]

for age in ages:
  if age >= 16:
    print(age)
# Out:
# 16
# 16
# 16
# 17
# 26

# %% [markdown]
# # Новый раздел

# %%
letters = list("Liza")

print(letters[0])
print(letters[-1])
# Out:
# L
# a

# %%
name = input("your name")
name = list(name)

print(name[0])
name[-1] = name[-1].upper()
print(name[-1])
# Out:
# your nameqwerty
# q
# Y

# %%
people = ["Tom", "Sam", "Bob"]
i = 0
while i < len(people):
  print(people[i])
  i += 1
# Out:
# Tom
# Sam
# Bob

# %%
liza_lyudkova = ("Tom", "Bob", "Alice", "Sam", "Tim", "Bill")

slice_people1 = people[:3]
print(slice_people1)

slice_people2 = people[1:3]
print(slice_people2)

slice_people3 = people[1:6:2]
print(slice_people3)
# Out:
# ['Elizabeth', 'Lyudkova']
# ['Lyudkova']
# ['Lyudkova']

# %%
name = input("ur name ")
name = list(name)

name.append("!")
print(name)
# Out:
# ur name qwerty
# ['q', 'w', 'e', 'r', 't', 'y', '!']

# %%
name = input("ur name ")
name = list(name)

name.append("!")

print(name)

# %%
import random

bot = random.randint(1, 100)

while True:

    player = int(input("Введите число от 1 до 100: "))


    if player < 1:
        print("Число должно быть в диапазоне от 1 до 100.")


    elif player > 100:
        print("Число должно быть в диапазоне от 1 до 100.")


    elif player > bot:
        print("Загаданное число меньше")

    elif player < bot:
        print("Загаданное число больше")

    else:
        print("Угадал")
        break
# Out:
# Введите свой вариант (1 - stone 2 - noz 3 - paper): 2
# Ничья
# Введите свой вариант (1 - stone 2 - noz 3 - paper): 3
# Ничья
# Введите свой вариант (1 - stone 2 - noz 3 - paper): 1
# Поражение
# Введите свой вариант (1 - stone 2 - noz 3 - paper): 2
# Победа
# Введите свой вариант (1 - stone 2 - noz 3 - paper): 3
# Победа
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1624/1765333255.py in <cell line: 0>()
#       6 while True:
#       7   computer = random.randint(1, 3)
# ----> 8   player = int(input("Введите свой вариант (1 - stone 2 - noz 3 - paper): "))
#       9
#      10   if computer == player:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
